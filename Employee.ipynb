# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('employee.csv')
print("Data Loaded Successfully")
# Out:
# Data Loaded Successfully

# %%
print("\nMissing values column-wise:")
print(data.isnull().sum())
# Out:
# Missing values column-wise:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
print("\nStatistical Info:")
print(data.describe(include='all'))
# Out:
# Statistical Info:
#         Education  JoiningYear       City  PaymentTier          Age Gender  \
# count        4653  4653.000000       4653  4653.000000  4653.000000   4653
# unique          3          NaN          3          NaN          NaN      2
# top     Bachelors          NaN  Bangalore          NaN          NaN   Male
# freq         3601          NaN       2228          NaN          NaN   2778
# mean          NaN  2015.062970        NaN     2.698259    29.393295    NaN
# std           NaN     1.863377        NaN     0.561435     4.826087    NaN
# min           NaN  2012.000000        NaN     1.000000    22.000000    NaN
# 25%           NaN  2013.000000        NaN     3.000000    26.000000    NaN
# 50%           NaN  2015.000000        NaN     3.000000    28.000000    NaN
# 75%           NaN  2017.000000        NaN     3.000000    32.000000    NaN
# max           NaN  2018.000000        NaN     3.000000    41.000000    NaN
#
# ...

# %%
print("\nData Types of Columns:")
print(data.dtypes)
# Out:
# Data Types of Columns:
# Education                    object
# JoiningYear                   int64
# City                         object
# PaymentTier                   int64
# Age                           int64
# Gender                       object
# EverBenched                  object
# ExperienceInCurrentDomain     int64
# LeaveOrNot                    int64
# dtype: object

# %%
print("\nSummary of Variable Types:")
print("Character (Object):", data.select_dtypes(include='object').columns.tolist())
print("Numeric:", data.select_dtypes(include=['int64', 'float64']).columns.tolist())
print("Logical (Boolean):", data.select_dtypes(include='bool').columns.tolist())
# Out:
# Summary of Variable Types:
# Character (Object): ['Education', 'City', 'Gender', 'EverBenched']
# Numeric: ['JoiningYear', 'PaymentTier', 'Age', 'ExperienceInCurrentDomain', 'LeaveOrNot']
# Logical (Boolean): []

# %%
if 'Salary' in df.columns:
    data['Salary_zscore'] = (data['Salary'] - data['Salary'].mean()) / data['Salary'].std()
    sns.boxplot(y=data['Salary_zscore'])
    plt.title('Z-Score Box Plot for Salary')
    plt.show()
else:
    print("\n' Salary' column not found for normalization.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 if 'Salary' in df.columns:
#       2     data['Salary_zscore'] = (data['Salary'] - data['Salary'].mean()) / data['Salary'].std()
#       3     sns.boxplot(y=df['Salary_zscore'])
#
# NameError: name 'df' is not defined
